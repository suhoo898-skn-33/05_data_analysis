# %% [markdown]
# # [2] Numpy: ndarray 인덱싱 및 슬라이싱

# %% [markdown]
# ### [실습 1] 인덱싱과 슬라이싱
#
#
# 1. 배열 `arr`에서 1번째 열만 추출
# 2. 배열 `arr`에서 2번째 행, 3번째 열의 값을 출력
# 3. 배열 `arr`에서 첫 번째 행부터 두 번째 행까지 선택하고, 0번째와 1번째 열만 추출
#
# ```python
# arr = np.array([[10, 20, 30], [40, 50, 60], [70, 80, 90]])
# ```

# %%
import numpy as np
arr = np.array([[10, 20, 30], [40, 50, 60], [70, 80, 90]])
result1 = arr[:,0]
print(result1)
# Out:
# [10 40 70]

# %%
result2 = arr[1][2]
print(result2)
# Out:
# 60

# %%
result3 = arr[:2, :2]
print(result3)
# Out:
# [[10 20]
#  [40 50]]

# %% [markdown]
# ### [실습 2] 팬시 인덱싱과 불리언 인덱싱
#
#
# 아래 배열에서 팬시 인덱싱과 불리언 인덱싱을 사용하여 다음 작업을 수행하세요.
#
# 1. 팬시 인덱싱을 사용하여 배열의 0번째, 2번째, 4번째 요소를 출력
# 2. 배열의 값 중 50보다 큰 값만 추출
#
# ```python
# 	arr = np.array([10, 20, 30, 40, 50, 60, 70])
# ```

# %%
import numpy as np
arr = np.array([10, 20, 30, 40, 50, 60, 70])
indicies = [0,2,4]
print(arr[indicies])
# Out:
# [10 30 50]

# %%
print(arr[[False, False, False, False, False, True, True]])
# Out:
# [60 70]

# %% [markdown]
# ### [실습 3] 제품 판매 데이터 분석
#
#
# 어느 마트에서 판매되는 제품들의 월별 매출량이 아래와 같이 주어졌습니다. 각각의 행은 제품을 나타내고, 열은 각 월의 판매량을 나타냅니다.
#
# 1. 월별 판매량이 200개 이상인 제품의 판매량을 선택하라.
# 2. 3월(세 번째 열)의 판매량이 100개 이하인 제품의 1월과 2월 판매량을 추출하라.
# 3. 2월(두 번째 열)의 판매량이 150개 이상인 제품들의 전체 월별 판매량을 출력하라.
#
# ```python
# sales = np.array([[120, 150, 100],
#                   [80, 90, 110],
#                   [200, 180, 220],
#                   [50, 45, 70],
#                   [300, 320, 310]])
# ```

# %%
import numpy as nop

sales = np.array([[120, 150, 100],
                  [80, 90, 110],
                  [200, 180, 220],
                  [50, 45, 70],
                  [300, 320, 310]])

result1 = sales[sales>200]
print(result1)
result2 = sales[sales[:, 2]<=100, 0:2]
print(result2)
result3 = sales[sales[:, 1]>=150, :]
print(result3)
# Out:
# [220 300 320 310]
# [[120 150]
#  [ 50  45]]
# [[120 150 100]
#  [200 180 220]
#  [300 320 310]]
