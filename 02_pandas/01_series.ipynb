# %% [markdown]
# # pandas

# %% [markdown]
# ## Pandas 자료형
# https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html
#
# - DataFrame
#   - 가로축과 세로축이 있는 엑셀과 유사한 데이터구조를 가진 자료형.
#   - 가로축은 로우(행), 세로축은 컬럼(열)이다.
# - Series
#   - Pandas의 1차원 데이터 구조이다.
#   - 데이터프레임의 각 컬럼은 모두 시리즈라는 자료형이다.
#   - 데이터프레임은 n개의 시리즈로 구성된다.
#   - 값(values)과 인덱스(index)를 함께 갖음.
#   - 결측치(NaN)를 표현할 수 있음.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in C:\Users\suhoo\miniforge3\envs\pystudy_env\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\suhoo\miniforge3\envs\pystudy_env\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\suhoo\miniforge3\envs\pystudy_env\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\suhoo\miniforge3\envs\pystudy_env\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\suhoo\miniforge3\envs\pystudy_env\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np
import pandas as pd

pd.__version__
# Out:
# '3.0.3'

# %% [markdown]
# ## Series
# 시리즈(Series)는 인덱스(라벨)가 있는 1차원 배열 형태의 데이터 구조로, 데이터와 해당 데이터에 대한 인덱스를 함께 저장한다.
#
# **주요 특징**
# 1. 시리즈는 데이터 및 관려 지수로 구성되며 숫자 인덱스가 자동으로 생성된다.
# 2. 인덱싱 : 라벨 기반 접근은 `loc`, 위치 기반 접근은 `iloc`을 사용한다. 각 데이터 포인트는 인덱스(라벨)을 통해 접근할 수 있다.
# 3. 동종 데이터 타입 : 시리즈 내의 모든 데이터는 동일한 데이터 타입이어야 한다.
# 4. 결측치(비어있는 값) 지원 : 시리즈는 결측치(NaN)을 지원하며 데이터가 누락된 경우에도 유연하게 처리
# 5. 다양한 데이터 소스 : 리스트, 배열, 딕셔너리 등 다양한 형식의 데이터를 기반으로 시리즈를 생성할 수 있다.

# %%
# Series 생성하기
stock_ser = pd.Series(['NVDA', 'MSFT', 'AMZN', 'AAPL', 'TSLA'], name='미국주식')    # 미국주식 티커
print(stock_ser)
print(type(stock_ser))
print(stock_ser.index)
print(stock_ser.name)
# Out:
# 0    NVDA
# 1    MSFT
# 2    AMZN
# 3    AAPL
# 4    TSLA
# Name: 미국주식, dtype: str
# <class 'pandas.Series'>
# RangeIndex(start=0, stop=5, step=1)
# 미국주식

# %%
# index를 지정하지 않은 시리즈 생성
ser = pd.Series(np.random.randn(5))
print(ser)  # 0부터 시작하는 index가 자동으로 추가
print(ser[0], ser[1], ser[2], ser[3], ser[4])
print(ser.index)
# Out:
# 0   -0.333037
# 1    0.888759
# 2   -1.036594
# 3   -1.574813
# 4   -1.505718
# dtype: float64
# -0.33303707627643003 0.8887586479824857 -1.0365941325770243 -1.5748131420417957 -1.5057183962011595
# RangeIndex(start=0, stop=5, step=1)

# %%
# index를 지정한 시리즈 생성
ser = pd.Series(np.random.randn(5), index=['A', 'B', 'C', 'D', 'E'])
print(ser)
# print(ser[0], ser[1], ser[2], ser[3], ser[4])     # KeyError
print(ser['A'], ser['B'], ser['C'], ser['D'], ser['E'])
print(ser.index)    # Index(['A', 'B', 'C', 'D', 'E'], dtype='str')
# Out:
# A   -1.279887
# B   -0.910050
# C    1.141295
# D    0.929262
# E   -0.716135
# dtype: float64
# -1.2798872006403905 -0.9100495647198454 1.1412947748732951 0.9292617646437739 -0.7161351101786126
# Index(['A', 'B', 'C', 'D', 'E'], dtype='str')

# %%
# 라벨 기반 접근 loc, 위치 기반 접근 iloc
ser = pd.Series(np.random.randn(5), index=['A', 'B', 'C', 'D', 'E'])

print("라벨 기반 접근: ", ser.loc['A'], ser.loc['B'], ser.loc['C'])
print("위치 기반 접근: ", ser.iloc[0], ser.iloc[1], ser.iloc[2])
# Out:
# 라벨 기반 접근:  -1.3079279877462686 -0.8875662968374378 -2.0372267567334377
# 위치 기반 접근:  -1.3079279877462686 -0.8875662968374378 -2.0372267567334377

# %%
# dict -> ser 변환
dct = {'a': 30, 'b': 40, 'c': 50}
ser = pd.Series(dct)
ser
# Out:
# a    30
# b    40
# c    50
# dtype: int64

# %%
# 날짜 인덱스 생성
date_index = pd.date_range('2026-05-28', periods=100)
# print(date_index)

# 정규분포를 이용한 시리즈 생성
ser = pd.Series(np.random.randn(100), index=date_index)
# print(ser)
ser.name = '정규분포값'
print(ser.loc['2026-06-22'])
ser
# Out:
# -0.4259886031556172
# 2026-05-28    1.721059
# 2026-05-29   -0.704337
# 2026-05-30    0.404585
# 2026-05-31   -0.725995
# 2026-06-01   -1.505732
#                 ...
# 2026-08-31    0.009991
# 2026-09-01    0.661305
# 2026-09-02   -0.681407
# 2026-09-03   -0.059059
# 2026-09-04   -0.953643
# Freq: D, Name: 정규분포값, Length: 100, dtype: float64

# %% [markdown]
# ### Series 속성

# %%
movies = ['토이스토리5', '눈동자', '슈퍼걸', '군체']
movies_ser = pd.Series(movies)
movies_ser
# Out:
# 0    토이스토리5
# 1       눈동자
# 2       슈퍼걸
# 3        군체
# dtype: str

# %%
print("dtype: ", movies_ser.dtype)
print("shape: ", movies_ser.shape)
print("size: ", movies_ser.size)
print("empty: ", movies_ser.empty)  # Series가 비어 있으면 True

# 모든 값이 유일하면 True(중복 값이 없으면 True)
print("is_unique: ", movies_ser.is_unique)
# Out:
# dtype:  str
# shape:  (4,)
# size:  4
# empty:  False
# is_unique:  True

# %% [markdown]
# ### Series 메서드

# %%
num_ser =pd.Series([300, 100, 500, 200, 400])
num_ser
# Out:
# 0    300
# 1    100
# 2    500
# 3    200
# 4    400
# dtype: int64

# %%
print("합계 : ", num_ser.sum())
print("평균 : ", num_ser.mean())
print("중앙값 : ", num_ser.median())
print("최솟값 : ", num_ser.min())
print("최댓값 : ", num_ser.max())
print("표준편차 : ", num_ser.std())
print("count : ", num_ser.count())
# Out:
# 합계 :  1500
# 평균 :  300.0
# 중앙값 :  300.0
# 최솟값 :  100
# 최댓값 :  500
# 표준편차 :  158.11388300841898
# count :  5

# %%
# 시리즈 설명
num_ser.describe()
# Out:
# count      5.000000
# mean     300.000000
# std      158.113883
# min      100.000000
# 25%      200.000000
# 50%      300.000000
# 75%      400.000000
# max      500.000000
# dtype: float64

# %%
num_ser.info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 5 entries, 0 to 4
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      int64
# dtypes: int64(1)
# memory usage: 172.0 bytes

# %% [markdown]
# ## S&P500
# - Pandas는 다양한 파일 형식의 데이터를 **읽고** **작성**할 수 있다.
# - 자주 사용하는 파일 형식으로 **CSV**, **Excel**, **JSON**, **SQL** 등이 있다.

# %%
# csv 읽어오기
snp500_df = pd.read_csv('./data/S_P500_Prices.csv')
print("데이터 타입: ", type(snp500_df))
print("행/렬: ", snp500_df.shape)
print("중복 행의 수: ", snp500_df.duplicated().sum())

print("조회된 데이터 중 맨 위 5개: ", snp500_df.head())
print("조회된 데이터 중 맨 아래 5개: ", snp500_df.tail())
# Out:
# 데이터 타입:  <class 'pandas.DataFrame'>
# 행/렬:  (2159, 1)
# 중복 행의 수:  12
# 조회된 데이터 중 맨 위 5개:           sp500
# 0  1295.500000
# 1  1289.089966
# 2  1293.670044
# 3  1308.040039
# 4  1314.500000
# 조회된 데이터 중 맨 아래 5개:              sp500
# 2154  3327.770020
# 2155  3349.159912
# 2156  3351.280029
# 2157  3360.469971
# 2158  3333.689941

# %%
# df -> ser 변환
# df.squeeze(): 컬럼이 1개인 df을 ser로 변환
snp500_ser = snp500_df.squeeze()
snp500_ser.info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 2159 entries, 0 to 2158
# Series name: sp500
# Non-Null Count  Dtype
# --------------  -----
# 2159 non-null   float64
# dtypes: float64(1)
# memory usage: 17.0 KB

# %%
print("전체 요소 개수(size):", snp500_ser.size)
print("전체 요소 개수(len):", len(snp500_ser))
print("not-null 데이터 개수(count):", snp500_ser.count())

print("최솟값:", snp500_ser.min())
print("최댓값:", snp500_ser.max())
print("평균:", snp500_ser.mean())
print("중앙값:", snp500_ser.median())
print("분산:", snp500_ser.var())
print("표준편차:", snp500_ser.std())

print("통계 요약:")
snp500_ser.describe()
# Out:
# 전체 요소 개수(size): 2159
# 전체 요소 개수(len): 2159
# not-null 데이터 개수(count): 2159
# 최솟값: 1278.040039
# 최댓값: 3386.149902
# 평균: 2218.7495540592868
# 중앙값: 2106.629883
# 분산: 288714.6381853397
# 표준편차: 537.3217268874763
# 통계 요약:
# count    2159.000000
# mean     2218.749554
# std       537.321727
# min      1278.040039
# 25%      1847.984985
# 50%      2106.629883
# 75%      2705.810059
# max      3386.149902
# Name: sp500, dtype: float64

# %%
# 데이터 정렬
snp500_ser.sort_values(ascending=True)  # 오름차순 정렬(기본값)
# snp500_ser.sort_values(ascending=False)  # 오름차순 정렬(기본값)
# Out:
# 97      1278.040039
# 98      1278.180054
# 99      1285.500000
# 1       1289.089966
# 2       1293.670044
#            ...
# 2038    3373.229980
# 2034    3373.939941
# 2033    3379.449951
# 2035    3380.159912
# 2037    3386.149902
# Name: sp500, Length: 2159, dtype: float64
